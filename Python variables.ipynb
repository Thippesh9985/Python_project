# %%
#Variable something where we can store the values in it.
#Variables are place holders, store it and it will useful for future purpose
#Variables should be single value there shouldn't any space ex: first value 
#Variables are case sensitive it means if we have defined variable name a = 10 and if we print(A) this will not work
#Variables are can support only one special character i.e., underscore '_'
#Variables cannot be keyvalues 
#Variable are changable overwritten
# For the string values give them in double quotes. Single quote also works but in cases when your value it self has single quotein such cases single quote doesn't work we must use double quote

# %%
first_var = "Jai Shri ram"   #Allowed
first var = "Jai Shri ram"   #Not allowed since there is a space (variables cannot be two words)
1st_var   = 1                #Not allowed (variable cannot start with numbers)
var_1st   = 1                #Allowed (Numbers can be in the middle or at the end)
_firstvar = 18               #Allowed (can start with _)
type      = "Str"            #Not allowed (keyvalues cannot be used as variable name)
print     = "Output"         #Not allowed

# %%
first_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 first_var
#
# NameError: name 'first_var' is not defined

# %%
first_var = "Jai Shri Ram"
# Out:
#   Cell In[13], line 2
#     First var = "Mean"
#           ^
# SyntaxError: invalid syntax

# %%
first_var
# Out:
# 'Jai Shri Ram'

# %%
first_var = "Jai Shree ram"

# %%
first_var
# Out:
# 'Jai Shree ram'

# %%
var_1st
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 var_1st
#
# NameError: name 'var_1st' is not defined

# %%
my_variable = "Thippesh"

# %%
my_variable.islower()
# Out:
# False

# %%
my_variable.isupper()
# Out:
# False

# %%
my_variable.lower()
# Out:
# 'thippesh'

# %%
my_variable.upper()
# Out:
# 'THIPPESH'

# %%
my_variable = "THIPPESH"

# %%
my_variable.isupper()
# Out:
# True

# %%
my_variable.swapcase()  #this will swap the case of the value
# Out:
# 'thippesh'

# %%
num_var= 200

# %%
num_var
# Out:
# 200

# %%
num_var.is_integer()
# Out:
# True

# %%
#Index start with '0'
#If you want to access the some part of your value then we need to provide start position and end position + 1
indexing_datatype = "Learning Python for the first time"

# %%
indexing_datatype[0] #to get the 0th position character from the value
# Out:
# 'L'

# %%
indexing_datatype[3]
# Out:
# 'r'

# %%
indexing_datatype[0:8] #to get the characters between 0 to 8th position
# Out:
# 'Learning'

# %%
indexing_datatype[30:34]
# Out:
# 'time'

# %%
indexing_datatype[0:10:2] #if we want to jump 1 character for the value "Learning " 0-10 this the value 'Lann ' will be output
# Out:
# 'Lann '

# %%
indexing_datatype[30:36:2]
# Out:
# 'tm'
